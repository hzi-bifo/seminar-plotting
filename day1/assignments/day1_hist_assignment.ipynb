# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Load the 'penguins.csv' file using read_csv as you learned before.

# %% [markdown]
# # Use df.columns in the same way as before to have a look at the vaiables

# %% [markdown]
# ###Using sns.histplot() function draw the histogram for the flipper length of the penguins. Provide the dataframe and in x, the column name of your choice.
# Use the functions:
# ```python
#
# plt.xlabel("X label", fontsize = 14) #to add an X, Y label and the title
# plt.ylabel("Y label", fontsize = 14)
# plt.title("Title", fontsize = 14)
#
# plt.show() # to show the figure
# #OR
# plt.savefig("figure_name.png", dpi=300) #to save the figure
# ```
# The histogram function is: sns.histplot(df, x = 'flipper_length_mm')  What do you observe?

# %% [markdown]
# # Experiment with different number of bins. Use the arg bins =  in the same function and plot it

# %% [markdown]
# # Experiment with different binwidth. Use the arg binwidth  in the same function and plot it

# %% [markdown]
# # Draw kde on top of the histogram to have a look at the distribution. To do so, use kde=True
